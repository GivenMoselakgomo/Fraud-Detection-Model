# %% [markdown]
# # 02 — Transaction EDA
# **FNB Intelligent Banking System | Data Science Team**
# **Sprint 0 — Notebook scaffold (no code yet)**
#
# ---
# **Notebook purpose:**
# Explore `transactions_data.csv` which maps to the **Transaction** entity.
# Goal: understand transaction volumes, amounts, merchant patterns, and errors.
#
# **Source file:** `data/transactions_data.csv`
# **Canonical entity:** Transaction (Section 3.3 of Project Definition)

# %% [markdown]
# ## 1. Imports & Setup

# %% [markdown]
# ## 2. Load Data
# Load `transactions_data.csv` from the `data/` folder.

# %% [markdown]
# ## 3. Data Overview
# Check shape, column names, data types, and sample rows.

# %% [markdown]
# ## 4. Missing Values & Data Quality
# Check for nulls, especially in `error_flag` and `is_fraud` columns.

# %% [markdown]
# ## 5. Transaction Amount Analysis
# Explore the distribution of `amount`. Look for outliers and unusual spikes.

# %% [markdown]
# ## 6. Transaction Volume Over Time
# Analyse how transaction volume changes over time using `transaction_date`.
# Look for daily, weekly, or seasonal patterns.

# %% [markdown]
# ## 7. Payment Method Analysis
# Explore `use_chip` values: Chip / Swipe / Contactless / Online.
# Which method is most common? Does it relate to fraud?

# %% [markdown]
# ## 8. Error Analysis
# Explore the `error_flag` column. What types of errors occur and how often?

# %% [markdown]
# ## 9. Key Findings & Notes

# %% [markdown]
# _Write your findings here._

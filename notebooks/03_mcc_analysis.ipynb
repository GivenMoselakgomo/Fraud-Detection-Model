# %% [markdown]
# # 03 — MCC Code Analysis
# **FNB Intelligent Banking System | Data Science Team**
# **Sprint 0 — Notebook scaffold (no code yet)**
#
# ---
# **Notebook purpose:**
# Analyse Merchant Category Codes (MCC) from `mcc_codes.json` joined with `transactions_data.csv`.
# Goal: identify high-risk merchant categories and spending patterns by business type.
#
# **Source files:** `data/mcc_codes.json`, `data/transactions_data.csv`
# **Relevant feature:** `high_risk_merchant` (Section 3.5 of Project Definition)

# %% [markdown]
# ## 1. Imports & Setup

# %% [markdown]
# ## 2. Load MCC Lookup Data
# Load `mcc_codes.json` — it maps 4-digit MCC codes to business type descriptions.

# %% [markdown]
# ## 3. Load Transactions & Join MCC
# Load transactions and join on `mcc_code` to enrich with business type descriptions.

# %% [markdown]
# ## 4. Top Merchant Categories by Volume
# Which merchant types have the highest number of transactions?

# %% [markdown]
# ## 5. High-Risk Merchant Category Identification
# Define a list of high-risk MCC categories (e.g. gambling, crypto exchanges, money transfer).
# Flag transactions that fall into these categories.

# %% [markdown]
# ## 6. High-Risk Category vs Fraud Rate
# Compare fraud rates between high-risk and non-high-risk merchant categories.

# %% [markdown]
# ## 7. Key Findings & Notes

# %% [markdown]
# _Write your findings here._

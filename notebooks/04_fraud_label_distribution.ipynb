# %% [markdown]
# # 04 — Fraud Label Distribution
# **FNB Intelligent Banking System | Data Science Team**
# **Sprint 0 — Notebook scaffold (no code yet)**
#
# ---
# **Notebook purpose:**
# Analyse the `train_fraud_labels.json` file and the `is_fraud` column in transactions.
# Goal: understand class imbalance and fraud patterns — critical for model training.
#
# **Source files:** `data/train_fraud_labels.json`, `data/transactions_data.csv`
# **Key concern:** Class imbalance (fraud is rare — model must still detect it)

# %% [markdown]
# ## 1. Imports & Setup

# %% [markdown]
# ## 2. Load Fraud Labels
# Load `train_fraud_labels.json` — format is `{ transaction_id: is_fraud ("Yes"/"No") }`.

# %% [markdown]
# ## 3. Merge Labels with Transactions
# Join fraud labels onto the transactions DataFrame on `transaction_id`.

# %% [markdown]
# ## 4. Class Imbalance Check
# How many fraudulent vs non-fraudulent transactions are there?
# Calculate the percentage of fraud in the dataset.

# %% [markdown]
# ## 5. Fraud by Transaction Amount
# Are fraudulent transactions typically higher or lower in amount than legitimate ones?

# %% [markdown]
# ## 6. Fraud by Payment Method
# Is fraud more common with Chip / Swipe / Contactless / Online transactions?

# %% [markdown]
# ## 7. Fraud Over Time
# Does the frequency of fraud change over time? Any suspicious spikes?

# %% [markdown]
# ## 8. Key Findings & Notes
# Note the imbalance ratio and any patterns found — this will directly inform the SMOTE strategy in Sprint 4.

# %% [markdown]
# _Write your findings here._
